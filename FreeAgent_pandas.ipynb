# %%
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
descr = pd.read_csv('attributes_report.csv')
descr_1 = pd.read_csv('attributes_report_1.csv')

# %%
descr.head()
# Out:
#    company        company_type  subscribed_after_free_trial
# 0   346782  uk_limited_company                        False
# 1   346783  uk_limited_company                        False
# 2   346784  uk_limited_company                         True
# 3   346785  uk_limited_company                        False
# 4   346786  uk_limited_company                        False

# %%
active = pd.read_csv('engagement_report.txt', sep=" ", header=None)
active.columns = ["1", "company", "2", "3", "logging","5","6","7","8"]

# %%
active.head()
# Out:
#          1  company       2   3  logging      5   6    7  8
# 0  company   346782  logged  in        1  times  on  day  0
# 1  company   346782  logged  in        0  times  on  day  1
# 2  company   346782  logged  in        1  times  on  day  2
# 3  company   346782  logged  in        0  times  on  day  3
# 4  company   346782  logged  in        1  times  on  day  4

# %%
group = active.groupby("company")[["logging"]].agg(np.sum)
group.to_csv("group.csv")
group.head(10)
# Out:
#          logging
# company
# 346782         3
# 346783         0
# 346784         7
# 346785         0
# 346786         0
# 346787         1
# 346788         0
# 346789         0
# 346790         0
# 346791         2

# %%
descr["subscribed_after_free_trial"] = descr["subscribed_after_free_trial"].astype('category').cat.codes
descr["company_type"] = descr["company_type"].astype('category').cat.codes

# %%
descr.shape
# Out:
# (950, 3)

# %%
cross = pd.merge(group,descr, on=['company','company'])

# %%
cross.head(10)
# Out:
#    company  logging  company_type  subscribed_after_free_trial
# 0   346782        3             0                            0
# 1   346783        0             0                            0
# 2   346784        7             0                            1
# 3   346785        0             0                            0
# 4   346786        0             0                            0
# 5   346787        1             0                            0
# 6   346788        0             0                            0
# 7   346789        0             0                            0
# 8   346790        0             0                            0
# 9   346791        2             0                            0

# %%
cross.to_csv("final.csv")

# %%
cross.corr()
# Out:
#                               company   logging  company_type  \
# company                      1.000000 -0.093484      0.882688
# logging                     -0.093484  1.000000     -0.118363
# company_type                 0.882688 -0.118363      1.000000
# subscribed_after_free_trial -0.105476  0.862992     -0.129922
#
#                              subscribed_after_free_trial
# company                                        -0.105476
# logging                                         0.862992
# company_type                                   -0.129922
# subscribed_after_free_trial                     1.000000

# %%
import seaborn as sns

# %%
active_count = group_2['logging'].value_counts()
sns.set(style="darkgrid")
sns.barplot(group_2.index, group_2.values, alpha=0.9)
plt.title('Disctribution')
plt.ylabel('Number of logging', fontsize=12)
plt.xlabel('Subscribe', fontsize=12)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-70-d1d9be264312> in <module>()
#       1 #active_count = group_2['logging'].value_counts()
#       2 sns.set(style="darkgrid")
# ----> 3 sns.barplot(group_2.index, group_2.values, alpha=0.9)
#       4 plt.title('Disctribution')
#       5 plt.ylabel('Number of logging', fontsize=12)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3147                           estimator, ci, n_boot, units,
#    3148                           orient, color, palette, saturation,
# -> 3149                           errcolor, errwidth, capsize, dodge)
#    3150
#    3151     if ax is None:
#
# ...

# %%
group_2 = cross.groupby("logging")[["subscribed_after_free_trial"]].agg(np.sum)
group_2.head(17)
# Out:
#          subscribed_after_free_trial
# logging
# 0                                  0
# 1                                  0
# 2                                  0
# 3                                  2
# 4                                  4
# 5                                 14
# 6                                 16
# 7                                 32
# 8                                 16
# 9                                 20
# 10                                18
# 11                                21
# 12                                 8
# 13                                 6
# 14                                 1
# 15                                 2
# 18                                 1
